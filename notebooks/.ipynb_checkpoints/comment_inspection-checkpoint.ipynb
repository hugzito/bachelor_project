# %% [markdown]
# # Imports

# %%
import sys
sys.path.append('../')

import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, SpectralClustering, BisectingKMeans, AgglomerativeClustering, FeatureAgglomeration
from scipy.spatial import distance
import matplotlib.pyplot as plt
from embedding_functions_hugo.embedding_functions import *

# %% [markdown]
# # Data Grabbing

# %%
# subreddit dataframes with comments
df_gaming = pd.read_csv('../data/scrapes/gaming.csv')
df_satis = pd.read_csv('../data/scrapes/SatisfactoryGame.csv')
df_marauders = pd.read_csv('../data/scrapes/MaraudersGame.csv')
df_tarkov = pd.read_csv('../data/scrapes/EscapefromTarkov.csv')
df_politics = pd.read_csv('../data/scrapes/politics.csv')

# loading embeddings
politics_embeddings = np.load('../data/embeddings/politics_embeddings.npy')
gaming_embeddings = np.load('../data/embeddings/gaming_embeddings.npy')
marauders_embeddings = np.load('../data/embeddings/marauders_embeddings.npy')
tarkov_embeddings = np.load('../data/embeddings/tarkov_embeddings.npy')
satisfactory_embeddings = np.load('../data/embeddings/satisfactory_embeddings.npy')

# loading large embeddings
politics_embeddings_large = np.load('../data/big_embeddings/politics.npy')
gaming_embeddings_large = np.load('../data/big_embeddings/gaming.npy')
tarkov_embeddings_large = np.load('../data/big_embeddings/Tarkov.npy')
marauders_embeddings_large = np.load('../data/big_embeddings/Marauders.npy')
satisfactory_embeddings_large = np.load('../data/big_embeddings/Satisfactory.npy')

# %% [markdown]
# # Functions

# %%
# shortening and cleaning function
def shorten_and_clean_dataset (comment_csv, comment_column : str, desired_comment_length : int):
    dataframe = pd.read_csv(comment_csv)
    dataframe['cleaned_text'] = prep_pipeline(dataframe, comment_column)
    dataframe['short'] = shorten_sens(dataframe['cleaned_text'], desired_comment_length)
    return dataframe

# function for creating and saving embeddings
def save_embeddings_as_npy(destination_path : str, comment_csv, comment_column : str, desired_comment_length : int):
    '''
    Nlp pipeline function which takes a pandas dataframe and relevant columns, performs preprocessing steps, uses sentence_transformer embeddings and saves the embeddings as a csv file.
    '''
    sentences = shorten_and_clean_dataset(comment_csv, comment_column, desired_comment_length)
    embeddings = embed_comments(sentences['short'])
    return np.save(destination_path, embeddings)

def pair_users_embeddings(dataframe, embeddings, average_out_comments = False):
    usernames = dataframe['comment_author']
    user_dictionary = {}
    for author, embedded_comment in zip(usernames, embeddings):
        if author not in user_dictionary.keys():
            user_dictionary[author] = []
            user_dictionary[author].append(embedded_comment)
        else:
            user_dictionary[author].append(embedded_comment)
    if average_out_comments:
        for user in user_dictionary:
            number_or_comments = len(user_dictionary[user])
            user_dictionary[user] = sum(user_dictionary[user])/number_or_comments
    return user_dictionary

# %% [markdown]
# # Other prep
#
# ## Adding Cleaned Comments

# %%
df_politics['cleaned_text'] = prep_pipeline(df_politics, 'comment_text', loud=False)
df_politics['short'] = shorten_sens(df_politics['cleaned_text'], 50)

df_gaming['cleaned_text'] = prep_pipeline(df_gaming, 'comment_text', loud=False)
df_gaming['short'] = shorten_sens(df_gaming['cleaned_text'], 50)

df_tarkov['cleaned_text'] = prep_pipeline(df_tarkov, 'comment_text', loud=False)
df_tarkov['short'] = shorten_sens(df_tarkov['cleaned_text'], 50)

df_marauders['cleaned_text'] = prep_pipeline(df_marauders, 'comment_text', loud=False)
df_marauders['short'] = shorten_sens(df_marauders['cleaned_text'], 50)

df_satis['cleaned_text'] = prep_pipeline(df_satis, 'comment_text', loud=False)
df_satis['short'] = shorten_sens(df_satis['cleaned_text'], 50)

# %% [markdown]
# # Comment Inspection
#
# ## Quick Prep (r/politics)

# %%
politics_user_embeddings = pair_users_embeddings(df_politics, politics_embeddings, True)

# Set PCA to desired number of dimensions
pca = PCA(n_components=2)

pca_embeddings = pca.fit_transform(list(politics_user_embeddings.values()))

kmeans = KMeans(n_clusters=2, random_state=0)

classes = kmeans.fit_predict(pca_embeddings)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ## Horizontally distant

# %%
#print(pca_embeddings.shape)
#print(len(politics_user_embeddings.keys()), len(politics_user_embeddings.values()))

# finding indexes of rows with least and max x values

x_vals = []
for idx, row in enumerate(pca_embeddings):
    x_val = row[0]
    x_vals.append(x_val)

# least x
least_x = min(x_vals)
least_x_index = np.argmin(x_vals)
least_x_username = list(politics_user_embeddings.keys())[least_x_index]
least_x_comments = df_politics.loc[df_politics['comment_author'] == least_x_username]

max_x = max(x_vals)
max_x_index = np.argmax(x_vals)
max_x_username = list(politics_user_embeddings.keys())[max_x_index]
max_x_comments = df_politics.loc[df_politics['comment_author'] == max_x_username]

#print(least_x, least_x_index, least_x_username)
#print(max_x, max_x_index, max_x_username)

#print(df_politics.shape)
#print(len(politics_user_embeddings.keys()))
print('===== Lowest x coord comment =====')
print(least_x_comments['comment_text'].values[0])
print('\n===== Highest x coord comment =====')
print(max_x_comments['comment_text'].values[0])
# Out:
# ===== Lowest x coord comment =====
# Love how the GOP rails against the illegals coming in and yet this mother fucker has been in the US illegally for 15 years, cannot even vote in US elections and tried to assassinate the Speaker of the House. But the Mexicans…right. So illegals bad when they’re brown but when they’re delusional Canadian psychos who are white….it’s all good.
#
# ===== Highest x coord comment =====
# Somebody call JG Wentworth.

# %% [markdown]
# ## Vertically distant

# %%
#print(pca_embeddings.shape)
#print(len(politics_user_embeddings.keys()), len(politics_user_embeddings.values()))

# finding indexes of rows with least and max y values

y_vals = []
for idx, row in enumerate(pca_embeddings):
    y_val = row[1]
    y_vals.append(y_val)

# least y
least_y = min(y_vals)
least_y_index = np.argmin(y_vals)
least_y_username = list(politics_user_embeddings.keys())[least_y_index]
least_y_comments = df_politics.loc[df_politics['comment_author'] == least_y_username]

max_y = max(y_vals)
max_y_index = np.argmax(y_vals)
max_y_username = list(politics_user_embeddings.keys())[max_y_index]
max_y_comments = df_politics.loc[df_politics['comment_author'] == max_y_username]

#print(least_y, least_y_index, least_y_username)
#print(max_y, max_y_index, max_y_username)

#print(df_politics.shape)
#print(len(politics_user_embeddings.keys()))
print('===== Lowest y coord comment =====')
print(least_y_comments['comment_text'].values[0])
print()
print('===== Highest y coord comment =====')
print(max_y_comments['comment_text'].values[0])
# Out:
# ===== Lowest y coord comment =====
# From a New Republic article:
#
# Santos has claimed a net worth as high as $11.5 million—all from the newly formed Devolder Organization from which Santos claimed to receive a $750,000 salary and between $1 and $5 million in dividends. Gaetz followed up on Santos’s quip, giving him an easy out to offer any simple explanation for where the money came from. Instead, Santos remained cryptic and even more dishonest.
#
# ===== Highest y coord comment =====
# oh they are not gonna like that, they are not gonna like that at all.

# %% [markdown]
# ## Most distant (in progress)

# %%
def most_distant(df, embeddings, n=3):
    '''
    inputs:
     - df: df to work with
     - embeddings: embeddings to work with
     - n: number of most distant user-pairs to print
    
    Function calculates the distance between all user pairs and sorts them from most to least distant.
    n number of user-pairs have their comments printed
    '''
    
    # pairing embeddings
    user_embeddings = pair_users_embeddings(df, embeddings, True)
    
    # doing pca things
    pca = PCA(n_components=2)
    pca_embeddings = pca.fit_transform(list(user_embeddings.values()))
    kmeans = KMeans(n_clusters=2, random_state=0)
    classes = kmeans.fit_predict(pca_embeddings)
    
    # print blob
    label_color_map = {0 : 'r',1 : 'g'}
    label_color = [label_color_map[l] for l in classes]
    plt.scatter(pca_embeddings[:,0], pca_embeddings[:,1], c=label_color)
    
    distance_list = list() # list for keeping track of maximum distances, index matches the user the distance is from
    distance_to_whom_list = list() # list for keeping track of the index of the user the distance is to
    
    num_rows = pca_embeddings.shape[0]
    print(f'looping through {num_rows} rows, this may take a few mins...')
    
    # looping through embeddings to loop through users
    for idx_a, row_a in enumerate(pca_embeddings):
        x_val_a = row_a[0]
        y_val_a = row_a[1]
        
        max_distance = 0.0
        to_whom_index = 0
        for idx_b, row_b in enumerate(pca_embeddings):
            x_val_b = row_b[0]
            y_val_b = row_b[1]
            
            # calculating euclidean distance
            a = (x_val_a, y_val_a)
            b = (x_val_b, y_val_b)
            dist = distance.euclidean(a, b)
            
            # saving to distance_list and distance_to_whom_list
            if dist > max_distance:
                max_distance = dist
                to_whom_index = idx_b
        
        distance_list.append(max_distance)
        distance_to_whom_list.append(to_whom_index)
    
    # sorting distance_list
    top_n_distances = np.sort(distance_list)
    top_n_indexes = np.argsort(distance_list)[-n:]
    
    #print(top_n_distances)
    #print(top_n_indexes)
    
    n_pairs = dict()
    for a_idx in top_n_indexes:
        n_pairs[a_idx] = [distance_to_whom_list[a_idx], top_n_distances[a_idx]]
    
    #print(n_pairs)
    
    # gettings comments of pairs and printing them
    usernames_a = list()
    for index in n_pairs.keys():
        username = list(user_embeddings.keys())[index]
        usernames_a.append(username)
    
    usernames_b = list()
    for index in list(n_pairs.values()):
        username = list(user_embeddings.keys())[index[0]]
        usernames_b.append(username)
    
    for pair in zip(usernames_a, usernames_b):
        username_a = pair[0]
        username_b = pair[1]
        
        comments_a = df.loc[df['comment_author'] == username_a]
        comments_b = df.loc[df['comment_author'] == username_b]
        
        print(f'\n===== Pair between {username_a} and {username_b} =====')
        print(f' == {username_a}:\n{comments_a["short"].values[0]}')
        print(f' == {username_b}:\n{comments_b["short"].values[0]}')
    
    return

# %%
print(df_satis.loc[df_satis['comment_author'] == 'Hob_O_Rarison']['comment_text'].values[0])
print(df_satis.loc[df_satis['comment_author'] == 'Hob_O_Rarison']['short'].values[0])
# Out:
# Dyson Sphere Project + Norm Mcdonald Has A Show.
#
# I have no idea what that is, like one of those weird 3-colored basket balls, which is fine now.
# dyson sphere project  norm mcdonald has a show
#
# i have no idea what that is like one of those weird 3colored basket balls which is fine now

# %%
# pairing embeddings
user_embeddings = pair_users_embeddings(df_satis, satisfactory_embeddings, True)

# doing pca things
pca = PCA(n_components=2)
pca_embeddings = pca.fit_transform(list(user_embeddings.values()))
kmeans = KMeans(n_clusters=2, random_state=0)
classes = kmeans.fit_predict(pca_embeddings)

print(pca_embeddings[456])
print(pca_embeddings[1435])
print(pca_embeddings[1425])
print(pca_embeddings[2599])
print(pca_embeddings[2322])
print(pca_embeddings[2429])

print(list(user_embeddings.keys())[1435])
print(df_satis.loc[df_satis['comment_author'] == list(user_embeddings.keys())[1435]]['short'].values[0])
print(list(user_embeddings.keys())[1425])
print(df_satis.loc[df_satis['comment_author'] == list(user_embeddings.keys())[1425]]['short'].values[0])
print(list(user_embeddings.keys())[2599])
print(df_satis.loc[df_satis['comment_author'] == list(user_embeddings.keys())[2599]]['short'].values[0])
print(list(user_embeddings.keys())[2322])
print(df_satis.loc[df_satis['comment_author'] == list(user_embeddings.keys())[2322]]['short'].values[0])
print(list(user_embeddings.keys())[2429])
print(df_satis.loc[df_satis['comment_author'] == list(user_embeddings.keys())[2429]]['short'].values[0])
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# [16.13652855 -6.54112173]
# [-7.08880951 -0.07425039]
# [-7.08880951 -0.07425039]
# [-7.08880951 -0.07425039]
# [-7.08880951 -0.07425039]
# [-7.08881018 -0.07425037]
# renchiks2001
# gives me subnautica vibes i like this
# LaurelRaven
# looks a lot more like outer worlds but i really like it
# OneofLittleHarmony
# i sailed the high seas yonder or the years past
# madkem1
# gifgiphywmkromrtffhpw
# Corgi_nator
# i know a civil engineer who appreciates  your work

# %%
most_distant(df_satis, satisfactory_embeddings_large, n=20)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# looping through 2161 rows, this may take a few mins...
#
# ===== Pair between krazyjakee and Huntyoudownn =====
#  == krazyjakee:
# in satisfactory time that is like 4 seconds what the fuck
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between jaded_Eclipse and Huntyoudownn =====
#  == jaded_Eclipse:
# would the planet crafter fall under this aswell also yea that is definitely an interesting theory
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between tethered_end and Huntyoudownn =====
#  == tethered_end:
# man i want one
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between LeMolle and US_Dept_of_Defence =====
#  == LeMolle:
# world of warcraft  paw patrol  world of pawcraft
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# ===== Pair between Hob_O_Rarison and US_Dept_of_Defence =====
#  == Hob_O_Rarison:
# dyson sphere project  norm mcdonald has a show
#
# i have no idea what that is like one of those weird 3colored basket balls which is fine now
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# ===== Pair between SoleTwentyCharacters and Roseknight888 =====
#  == SoleTwentyCharacters:
# wait till you get to turbo motors
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between Acrobatic-Truth and Huntyoudownn =====
#  == Acrobatic-Truth:
# those who click play but never launch the game due to shit pc
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between jorn86 and Roseknight888 =====
#  == jorn86:
# can we please do things that will actually matter to the games quality instead
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between KretzKid and Roseknight888 =====
#  == KretzKid:
# this would be a great post for their forum
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between AegisZieg and Roseknight888 =====
#  == AegisZieg:
# hahaha i am at that point in this save and i run around to the nodes i need to taplook at a central locationthen save and log
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between Structuraldefectx and Roseknight888 =====
#  == Structuraldefectx:
# johnny discovered you
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between Substantial_Bag_9536 and Roseknight888 =====
#  == Substantial_Bag_9536:
# me  oh my god this spider is creepy glad she is aw
# spider  jump
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# ===== Pair between TobbieDatBoi and Huntyoudownn =====
#  == TobbieDatBoi:
# looks amazing man straight outta the future
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between SelfMadeSoul and Huntyoudownn =====
#  == SelfMadeSoul:
# knock knock
#
# hi we are jenovas witnesses we would like to talk to you about our lord and saviour sephiroth
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between Hera_the_otter and Huntyoudownn =====
#  == Hera_the_otter:
# remember there are no labor laws or unions in space
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between Roseknight888 and Huntyoudownn =====
#  == Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# ===== Pair between MinaLamia and US_Dept_of_Defence =====
#  == MinaLamia:
# i have taken notes for three games satisfactory stardew and shadow empire
#
# kind of weird they all start with s
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# ===== Pair between Objective-Carob-5336 and US_Dept_of_Defence =====
#  == Objective-Carob-5336:
# my 1 rule on steam is never under 50 off
#
# this rule has saved me so much money and helped refrain any shopping spree in the past
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# ===== Pair between Huntyoudownn and US_Dept_of_Defence =====
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# ===== Pair between US_Dept_of_Defence and Huntyoudownn =====
#  == US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#  == Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all

# %%
most_distant(df_politics, politics_embeddings_large, n=20)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# looping through 8088 rows, this may take a few mins...
#
# ===== Pair between SonicView0088 and Neighthianael =====
#  == SonicView0088:
# why is all this nonsense about santos just coming out now how was not this all uncovered while he was running
#  == Neighthianael:
# that is it
#
# ===== Pair between Fitz911 and Neighthianael =====
#  == Fitz911:
# haha no he did not
#
# i will bet everything i have that this number is waaay to small not even with a factor of 10 this information is just not right one million that we know of
#  == Neighthianael:
# that is it
#
# ===== Pair between KNYLJNS and fistofthefuture =====
#  == KNYLJNS:
# why is he still there to begin with
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between Specific-Aide9475 and fistofthefuture =====
#  == Specific-Aide9475:
# i am going to be in canada next year the us literally feels like it is moving backwards
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between ispeakdatruf and fistofthefuture =====
#  == ispeakdatruf:
# of course they will do it now when they do not have a majority in the house what the fuck were they doing for the past 2 years
#
# edit i stand corrected looks like he is been introducing it for the past decade
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between sirscrote and fistofthefuture =====
#  == sirscrote:
# i wish john kelly would say more he is a retired general is he not spill the beans as to why you left
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between _SewYourButtholeShut and Neighthianael =====
#  == _SewYourButtholeShut:
# crazy to think that an expresident admitting over 400 times that his answers to questions under oath would incriminate him is not a blockbuster news story it is just monday
#  == Neighthianael:
# that is it
#
# ===== Pair between jenlucce and Neighthianael =====
#  == jenlucce:
# doubt anything would happen these people never really face any consequences
#  == Neighthianael:
# that is it
#
# ===== Pair between EmEffArrr1003 and Neighthianael =====
#  == EmEffArrr1003:
# fascists are always cowards  they do not project strength they hide behind it  they do not have ideas they spread fear and panic about other peoples ideas they have no purpose to their power except to accumulate more of it
#  == Neighthianael:
# that is it
#
# ===== Pair between Picasso5 and Neighthianael =====
#  == Picasso5:
# it is easy to dismiss these guys as stupid or crazy most likely both but the problem is these guys exist a lot of them so when they turn on right wing radio watch fox news listen to trump or his acolytes they are emboldening these maniacs even if the
#  == Neighthianael:
# that is it
#
# ===== Pair between TimidTurkey_321 and fistofthefuture =====
#  == TimidTurkey_321:
# yeah because severely weakening our countries defense does not make us look weak or anything
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between srodden1 and fistofthefuture =====
#  == srodden1:
# fucking finally most shady political shit stems from this piece of shit ruling
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between BendersBlender and fistofthefuture =====
#  == BendersBlender:
# unfortunately the disparity is too great and the top 101 are too powerful
#
# any change will be met with severe astroturfing propaganda and because more turmoil
#
# i do not have the solution but we have already seen the power of money in politics
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between SkeletonLad and fistofthefuture =====
#  == SkeletonLad:
# ban all indoctrination solved stfu about all your beliefs
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between noeydoesreddit and fistofthefuture =====
#  == noeydoesreddit:
# if you read the full article senator megan hunt states that if her amendment somehow garnered the votes to pass she would withdraw it
#
# am i the only one who thinks an amendment banning childhood religious indoctrination should be a real thing
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between tacticalcop and Neighthianael =====
#  == tacticalcop:
# good now get rid of him
#  == Neighthianael:
# that is it
#
# ===== Pair between khain13 and fistofthefuture =====
#  == khain13:
# good screw that guy i get that they all lie but man that was just excessive and every day they keep uncoving more insane lies
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between Neighthianael and fistofthefuture =====
#  == Neighthianael:
# that is it
#  == fistofthefuture:
# fuck this guy but i will take his bill
#
# ===== Pair between fistofthefuture and Neighthianael =====
#  == fistofthefuture:
# fuck this guy but i will take his bill
#  == Neighthianael:
# that is it
#
# ===== Pair between MarmaladeBoy20 and fistofthefuture =====
#  == MarmaladeBoy20:
# kick out all of the crooks
#  == fistofthefuture:
# fuck this guy but i will take his bill

# %%
most_distant(df_gaming, gaming_embeddings_large, n=20)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# looping through 11826 rows, this may take a few mins...
#
# ===== Pair between SPBD33 and masterlight123 =====
#  == SPBD33:
# bravo
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between banana_stealer_ and masterlight123 =====
#  == banana_stealer_:
# sanicu
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Garlic_Bread_Man_NSW and masterlight123 =====
#  == Garlic_Bread_Man_NSW:
# oh my god its so cute
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Iwantmahandback and Reis-iBuca =====
#  == Iwantmahandback:
# country boys make do
#  == Reis-iBuca:
# i am here before the  award
#
# ===== Pair between EinharAesir and masterlight123 =====
#  == EinharAesir:
# the reason they are doing it is because they can  i do not buy the excuses that games are expensive to produce when the video games industry takes in billions of dollars in profits
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Dark-Ganon and masterlight123 =====
#  == Dark-Ganon:
# female versus male butts in cyberpunk 2077 video games
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between smallshotfunshot and masterlight123 =====
#  == smallshotfunshot:
# not in them biscuit baskets gurl
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between _jukmifgguggh and masterlight123 =====
#  == _jukmifgguggh:
# thicc
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Different_Host6527 and masterlight123 =====
#  == Different_Host6527:
# the title makes it sound like his mom made the games he was the inspiration
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between OzairBoss and Mokari_Onedge =====
#  == OzairBoss:
# disgaea has entered the chat
#  == Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other
#
# ===== Pair between malkumecks and masterlight123 =====
#  == malkumecks:
# hey company  you should pay me   we have all been there
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between NukeCake and masterlight123 =====
#  == NukeCake:
# honestly might as well make the release date may 4th  would be sick for sure
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between stash3630 and masterlight123 =====
#  == stash3630:
# best assassins creed by a nautical mile
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Krakulpo and masterlight123 =====
#  == Krakulpo:
# you made the average scottish football fan
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between wright007 and masterlight123 =====
#  == wright007:
# for a second i thought you were referring to clippy and i was like did clippy really teach us anything
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between SkoomaJunki3 and masterlight123 =====
#  == SkoomaJunki3:
# meh that is pretty distracting i am going to
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between Reis-iBuca and Mokari_Onedge =====
#  == Reis-iBuca:
# i am here before the  award
#  == Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other
#
# ===== Pair between pseudoimpossibility and Mokari_Onedge =====
#  == pseudoimpossibility:
# i cannot see shit
#  == Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other
#
# ===== Pair between Mokari_Onedge and masterlight123 =====
#  == Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#
# ===== Pair between masterlight123 and Mokari_Onedge =====
#  == masterlight123:
# this motherfucker just went to google and searced up meme
#  == Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other

# %%
most_distant(df_tarkov, tarkov_embeddings_large, n=20)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# looping through 4589 rows, this may take a few mins...
#
# ===== Pair between coolhwip420 and Turok36 =====
#  == coolhwip420:
# this is basically every firefight for me though i literally just died on reserve like this
#  == Turok36:
# cringe
#
# ===== Pair between wilfulmarlin and Turok36 =====
#  == wilfulmarlin:
# the best part is since raiders can fuck people over you can stumble on someone who traded with a raider and get a full gear set without even having to pvp if you are lucky crazier things have happened
#  == Turok36:
# cringe
#
# ===== Pair between killjoySG and Cryovers =====
#  == killjoySG:
# i was in factory once to kill usec players and i came up on a japanese guy at forklift spawn i shot him up but he pulled out his knife and pleaded with me to spare him turns out he was doing an optional task of extracting via medtent but
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Yankthebandaid and Turok36 =====
#  == Yankthebandaid:
# and remove fir status on items let us buy sell and flip all items on flea again the changes only benefitted rmters that vacuum loot a map it fucked all the rest of us
#  == Turok36:
# cringe
#
# ===== Pair between Environmental-Wish35 and Cryovers =====
#  == Environmental-Wish35:
# had this happen to me on shoreline except i had basically nothing in my inventory  same exact rounds and everything i ran for a solid minute into the woods from svetly before i died from blunt force damage cheaters can eat shit
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Stunning_Language_25 and Cryovers =====
#  == Stunning_Language_25:
# killed someone doing the drop off quest of the sv98 and multi tool on shoreline did not even let him finish felt guilty
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Nockenwellensteuerun and Turok36 =====
#  == Nockenwellensteuerun:
# i am in support of this but only after the rampant cheating and rmt is taken care of that would allow those features to return without any risks and we could enjoy it organically why the fuck is not bsg banning people who sell like 16000 tetrizes on the flea
#  == Turok36:
# cringe
#
# ===== Pair between EokaBeamer and Turok36 =====
#  == EokaBeamer:
# can you make your point without writing a long ass essay you lost me after the title
#  == Turok36:
# cringe
#
# ===== Pair between thehairycarrot and Turok36 =====
#  == thehairycarrot:
# helmets are worthless  half this sub usually
#  == Turok36:
# cringe
#
# ===== Pair between jabralta and Cryovers =====
#  == jabralta:
# guess what people will still play even bought a nioce after the lip smack sound laptop to play on the road in my sleeper berth so you chumps cannot out level me supply and demand you cannot get this kind of hit anywhere else its cool find the new items
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between RedditErrorLog and Turok36 =====
#  == RedditErrorLog:
# well played dude
#  == Turok36:
# cringe
#
# ===== Pair between usprocksv2 and Cryovers =====
#  == usprocksv2:
# if you die in a suspicious way whatsoever would you report the person killing you  yes or no that is as basic of a question i can ask
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between 0verStrike and Turok36 =====
#  == 0verStrike:
# dude first guy did a reversed entry he deserves that  who tf enters a room with their backs towards the entrance id you cleared outiside the next possible danger is inside the room laugh my ass off
#  == Turok36:
# cringe
#
# ===== Pair between RainingBlood78 and Cryovers =====
#  == RainingBlood78:
# i laughed so much man oh my god
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Novel-Structure8660 and Turok36 =====
#  == Novel-Structure8660:
# i think you get killed from behind
#  == Turok36:
# cringe
#
# ===== Pair between BurgerChurger69 and Turok36 =====
#  == BurgerChurger69:
# exit camp factory with impacts
#  == Turok36:
# cringe
#
# ===== Pair between Jaysterlo_ and Turok36 =====
#  == Jaysterlo_:
# cheater problem aside this is fucking hilarious
#  == Turok36:
# cringe
#
# ===== Pair between regularknight and Cryovers =====
#  == regularknight:
# you see if you fold them a certain way you can fit so many
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Turok36 and Cryovers =====
#  == Turok36:
# cringe
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# ===== Pair between Cryovers and Turok36 =====
#  == Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#  == Turok36:
# cringe

# %%
most_distant(df_marauders, marauders_embeddings_large, n=20)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# looping through 332 rows, this may take a few mins...
#
# ===== Pair between DillyDilly1231 and waylonhall21 =====
#  == DillyDilly1231:
# i have got under 100 hours and i have done everything prestiging still feels useless they still have not fixed team queue bugs they still do not care about their audience just like bsg i know they said they took inspiration from tarkov but flat out ignoring the community that
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between Complete_Bagel and waylonhall21 =====
#  == Complete_Bagel:
# i have noticed this with all shotguns and to some degree all guns inconsistently hitting where they should either desync or so weird collision issue i do not know
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between xXAlche and Amigoodboy =====
#  == xXAlche:
# our universal i hear footsteps stop talking is anywhere between 3 aid 6 consecutive waits depending if they are still taking or not
#
# was not even agreed upon or anything we all just do it
#  == Amigoodboy:
# as i eat frozen pizza and smoke weed daily and am about to turn 29 this concerns me laughing out loud
#
# ===== Pair between JohnnyMcMoney and Realist419 =====
#  == JohnnyMcMoney:
# yeah my thoughts for 1500 hrs of tarkov as well
#  == Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#
# ===== Pair between ThatOneGuy6381 and Realist419 =====
#  == ThatOneGuy6381:
# last night was the first night i ever tried some terminator runs and its already dead wild
#  == Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#
# ===== Pair between thelostandfound618 and Realist419 =====
#  == thelostandfound618:
# 1010 update keep it going guys
#  == Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#
# ===== Pair between ReallyGottaTakeAPiss and scared_star =====
#  == ReallyGottaTakeAPiss:
# the fireman outfit we deserve
#  == scared_star:
# rip i liked that shotgun even before it was broken
#
# ===== Pair between RoyalSir and waylonhall21 =====
#  == RoyalSir:
# i am just starved for more content i have got 100 hours in and am bored that being said the core of this game is amazing it just needs more
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between Sors_Numine and waylonhall21 =====
#  == Sors_Numine:
# damn they straight killed the terminator
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between Alarming_Band_3759 and waylonhall21 =====
#  == Alarming_Band_3759:
# i think folded items should also shrink a tile
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between giacomopica and waylonhall21 =====
#  == giacomopica:
# man good to hear you are taking care of your health first marauders has also become one of my top games and while it is super fun it stresses me out more than any other game even tarkov somehow anyways good luck friend
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between Awkward-Celebration5 and waylonhall21 =====
#  == Awkward-Celebration5:
# i want the questlije to be less linear and able to tackle things kind of how tarkov does also the new contract thing needs to stop being how it is and have it be more like daily tasks also i like having 2 raid maps but we desperately need more
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between Beast_Mastese and waylonhall21 =====
#  == Beast_Mastese:
# i am still out there every day giving you guys marauder kills
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between xXRazihellXx and scared_star =====
#  == xXRazihellXx:
# yeah those are fast releif faster than liquigel
#  == scared_star:
# rip i liked that shotgun even before it was broken
#
# ===== Pair between dge001 and scared_star =====
#  == dge001:
# checkout the death certificate  on  deathverse let ut die it died with in the week of release  less than 100
#  == scared_star:
# rip i liked that shotgun even before it was broken
#
# ===== Pair between Amigoodboy and scared_star =====
#  == Amigoodboy:
# as i eat frozen pizza and smoke weed daily and am about to turn 29 this concerns me laughing out loud
#  == scared_star:
# rip i liked that shotgun even before it was broken
#
# ===== Pair between Realist419 and scared_star =====
#  == Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#  == scared_star:
# rip i liked that shotgun even before it was broken
#
# ===== Pair between scared_star and Realist419 =====
#  == scared_star:
# rip i liked that shotgun even before it was broken
#  == Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#
# ===== Pair between TheBigZamboni85 and waylonhall21 =====
#  == TheBigZamboni85:
# my advice is just shoot the damn gun and bring your best armor always bring your best what i mean is bring a ton of ammo and just fucking shoot pre fire everything you feel is sus or know a player is behind my friend noted i just mag dump
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# ===== Pair between waylonhall21 and TheBigZamboni85 =====
#  == waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#  == TheBigZamboni85:
# my advice is just shoot the damn gun and bring your best armor always bring your best what i mean is bring a ton of ammo and just fucking shoot pre fire everything you feel is sus or know a player is behind my friend noted i just mag dump

# %% [markdown]
# ## Similar Comments

# %%
def find_similar(df, embeddings):
    '''
    inputs:
     - df: df to work with
     - embeddings: embeddings to work with

    function finds similar groups of users in different areas of the embeddings space and prints one of their comments:
     - MIDDLE: All users around 0 (+/-0.1) are grouped, the amount of users here can vary
     - LEFT, RIGHT, TOP, BOTTOM: For each of these sides 5 users that are the most of them are grouped
    '''
    
    # pairing embeddings
    user_embeddings = pair_users_embeddings(df, embeddings, True)
    
    # doing pca things
    pca = PCA(n_components=2)
    pca_embeddings = pca.fit_transform(list(user_embeddings.values()))
    kmeans = KMeans(n_clusters=2, random_state=0)
    classes = kmeans.fit_predict(pca_embeddings)
    
    # print blob
    label_color_map = {0 : 'r',1 : 'g'}
    label_color = [label_color_map[l] for l in classes]
    plt.scatter(pca_embeddings[:,0], pca_embeddings[:,1], c=label_color)
    
    # finding similar things
    # NEED TO CODE FOR FINDING ALL FAR THINGS
    to_check = ['MIDDLE', 'LEFT', 'RIGHT', 'TOP', 'BOTTOM']
    
    for i in to_check:
        
        # finding x and y limits based off of blob
        
        if i == 'MIDDLE':
            print('========== MIDDLE ==========')
            x_lims = [-0.1, 0.1]
            y_lims = [-0.1, 0.1]
            
            similar_indexes = list()
            for idx, row in enumerate(pca_embeddings):
                x_val = row[0]
                y_val = row[1]
                
                if x_val > x_lims[0] and x_val < x_lims[1] and y_val > y_lims[0] and y_val < y_lims[1]:
                    similar_indexes.append(idx)
        
        # checks from far left and finds first 5 comments
        elif i == 'LEFT':
            print('========== LEFT ==========')
            # get list of x coords for sorting
            x_coords = list()
            for idx, row in enumerate(pca_embeddings):
                x_coords.append(row[0])
            
            # sorts x coords by ascending, but gives the indexes not the values
            sorted_indexes = np.argsort(x_coords)
            
            similar_indexes = sorted_indexes[:5]
        
        # checks from far left and finds first 5 comments
        elif i == 'RIGHT':
            print('========== RIGHT ==========')
            # get list of x coords for sorting
            x_coords = list()
            for idx, row in enumerate(pca_embeddings):
                x_coords.append(row[0])
            
            # sorts x coords by descending, but gives the indexes not the values
            initial_sort = np.argsort(x_coords)
            
            similar_indexes = initial_sort[::-1][:5] # 5 for first 5 comments
        
        # checks from far top and finds first 5 comments
        elif i == 'TOP':
            print('========== TOP ==========')
            # get list of y coords for sorting
            y_coords = list()
            for idx, row in enumerate(pca_embeddings):
                y_coords.append(row[1])
            
            # sorts y coords by descending, but gives the indexes not the values
            initial_sort = np.argsort(y_coords)
            
            similar_indexes = initial_sort[::-1][:5] # 5 for first 5 comments
        
        elif i == 'BOTTOM':
            print('========== BOTTOM ==========')
            # get list of y coords for sorting
            y_coords = list()
            for idx, row in enumerate(pca_embeddings):
                y_coords.append(row[1])
            
            # sorts y coords by ascending, but gives the indexes not the values
            sorted_indexes = np.argsort(y_coords)
            
            similar_indexes = sorted_indexes[:5]
            
        # using list of similar indexes, matches with users and prints their comments
        usernames = list()
        for index in similar_indexes:
            username = list(user_embeddings.keys())[index]
            usernames.append(username)

        # cleaning comments to get relevant ones in embedding space
        df['cleaned_text'] = prep_pipeline(df, 'comment_text', loud=False)
        df['short'] = shorten_sens(df['cleaned_text'], 50)
        
        for username in usernames:
            comments = df.loc[df['comment_author'] == username]
            #print(comments['comment_text'].values[0], '\n')
            print(f'{username}:')
            print(comments['short'].values[0], '\n')

# %%
find_similar(df_politics, politics_embeddings_large)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ========== MIDDLE ==========
# Whosebert:
# fascists this will show those snowflake dems
#
# reasonable citizens we want this too
#
# fascistsshit shit nevermind gdhhds
#
# Independent_Prune_35:
# what another lie good luck with that he will claim to have a disability and will sue you under the disabilities act for discrimination
#
# Skastrik:
# wonder what they will do when they realize his name is not george santos at all
#
# Ausgezeichnet87:
# republican blew 20 trillion on blowing up greatest of all time farmers in the middle east and now they are acting like the government is too broke pay our bills  invest in infrastructure or anything that helps workers
#
#
# it is all part of their starve the beast strategy
#
# ========== LEFT ==========
# fistofthefuture:
# fuck this guy but i will take his bill
#
# tacticalcop:
# good now get rid of him
#
# Picasso5:
# it is easy to dismiss these guys as stupid or crazy most likely both but the problem is these guys exist a lot of them so when they turn on right wing radio watch fox news listen to trump or his acolytes they are emboldening these maniacs even if the
#
# EmEffArrr1003:
# fascists are always cowards  they do not project strength they hide behind it  they do not have ideas they spread fear and panic about other peoples ideas they have no purpose to their power except to accumulate more of it
#
# _SewYourButtholeShut:
# crazy to think that an expresident admitting over 400 times that his answers to questions under oath would incriminate him is not a blockbuster news story it is just monday
#
# ========== RIGHT ==========
# khain13:
# good screw that guy i get that they all lie but man that was just excessive and every day they keep uncoving more insane lies
#
# Neighthianael:
# that is it
#
# MarmaladeBoy20:
# kick out all of the crooks
#
# noeydoesreddit:
# if you read the full article senator megan hunt states that if her amendment somehow garnered the votes to pass she would withdraw it
#
# am i the only one who thinks an amendment banning childhood religious indoctrination should be a real thing
#
# TimidTurkey_321:
# yeah because severely weakening our countries defense does not make us look weak or anything
#
# ========== TOP ==========
# finitecapacity:
# cannot wait for the impending biopic on this guy
#
# JasonZep:
# gop sounds like a mob
#
# orioncsky:
# 100 airlines will pass this cost to the consumers
#
# Euclidian1:
# stand by folks big hollywood movie  starring leonardo dicaprio catch me i will be damned in the works stand by for details
#
# clodzor:
# spend a million to discredit to get more donations to fight the corruption which he then pocketed
#
# ========== BOTTOM ==========
# iama_homosapien:
# i find this funny because i bet you anything if it was raised to 22 an hour you would have a lot more people applying and actually staying one of the reasons i quit was because i was not being paid enough for the amount of stress i was put
#
# hjablowme919:
# this is once again where having a voter base that is mostly ignorant plays in their favor the republicans are grandstanding that they are trying to cut spending but this is money for items in the current budget if they want to have the spending cuts conversation have it for
#
# MemnocOTG:
# he is like the political version of ezra miller
#
# hypedad__:
# a lot of fucking nails in this coffin to be fair
#
# For-All-the-Marbles:
# does congress not have rules of conduct against such conduct

# %%
find_similar(df_gaming, gaming_embeddings_large)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ========== MIDDLE ==========
# Uik44:
# still in college at 31 what are you studying
#
# ========== LEFT ==========
# Reis-iBuca:
# i am here before the  award
#
# pseudoimpossibility:
# i cannot see shit
#
# masterlight123:
# this motherfucker just went to google and searced up meme
#
# OzairBoss:
# disgaea has entered the chat
#
# mavrc:
# sooooo how is the difficulty level i am not very good
#
# ========== RIGHT ==========
# Mokari_Onedge:
# it reminds me of me preparing a university exam and forgetting about the other
#
# SkoomaJunki3:
# meh that is pretty distracting i am going to
#
# Krakulpo:
# you made the average scottish football fan
#
# wright007:
# for a second i thought you were referring to clippy and i was like did clippy really teach us anything
#
# stash3630:
# best assassins creed by a nautical mile
#
# ========== TOP ==========
# polishlastnames:
# my favorite was the bullet point they used to put on a lot of help articles
#
# google it
#
# Legion2567:
# that is because you have not played lost odyssey it is a crucial entry to the franchise
#
# StefanPlaysPOE:
# from a fellow gaming and arts enjoyer  these are amazing sir
#
# Firebat-045:
# smasmassmahsmash
#
# Jestersage:
# so respawn
#
#  you are delaying jedi survivor
#  you have no content for s15 and even upcoming s16 on apex
#  you are closing down apexm
#
# mmm
#
# ========== BOTTOM ==========
# tbuda88:
# what is up with the left dudes face
#
# DraconicWF:
# it is just that the 70 is kind of scummy it is clear that nintendo started the 70 with tears of the kingdom because they know with absolute certainty it is going to do insanely well
#
# halloweenjon:
# i was blown away by all these details in the gamecube version the best was when you donned the xray visor and looked at samus gun arm you could see her skeletal hand inside changing position for shooting different beams nuts
#
# gunswordfist:
# this is actually good casting
#
# LongJumpingBalls:
# that is clearly ai generated and you should change your style to make sure it does not look generated
#
# s
#
#
# looks great

# %%
find_similar(df_marauders, marauders_embeddings_large)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ========== MIDDLE ==========
# ========== LEFT ==========
# scared_star:
# rip i liked that shotgun even before it was broken
#
# giacomopica:
# man good to hear you are taking care of your health first marauders has also become one of my top games and while it is super fun it stresses me out more than any other game even tarkov somehow anyways good luck friend
#
# Beast_Mastese:
# i am still out there every day giving you guys marauder kills
#
# JohnnyMcMoney:
# yeah my thoughts for 1500 hrs of tarkov as well
#
# thelostandfound618:
# 1010 update keep it going guys
#
# ========== RIGHT ==========
# dge001:
# checkout the death certificate  on  deathverse let ut die it died with in the week of release  less than 100
#
# Realist419:
# more bumping than ever in my humble opinion the only thing that keeps dying is me
#
# waylonhall21:
# it is that capital ship the one with all the commandos on it because i just call it the commando ship laugh my ass off
#
# xXRazihellXx:
# yeah those are fast releif faster than liquigel
#
# Amigoodboy:
# as i eat frozen pizza and smoke weed daily and am about to turn 29 this concerns me laughing out loud
#
# ========== TOP ==========
# LokiBoi9000:
# fantastic game yes my only problem was that for some reason i got booted out of a match for no reason other than i think the anticheat thought i was cheating because i killed a guy from midrange with the liberator i killed the guy and poof back to the
#
# Twoj_stary221:
# me enjoying one marauder killed
#
# peep_da_toad:
# literally a pillhead laughing out loud
#
# Stylowar:
# as another tarkov vet who just got into it with 20 hours in 4 days yeah it was exactly what i thought too
#
# SoberOccassionally:
# get good kid
#
# ========== BOTTOM ==========
# kaimidoyouloveme:
# i agree so much of the game is really excellent really fast matchmakingload times seamless multiinstance raids with the different ships and pois really cool aesthetics and artwork solid ai enemies when its working as intended it is pretty incredible but it is not going to hold people until there
#
# JoseJalapenoOnStick:
# i did not know captain birdseye played marauders
#
# YourBoyBone:
# yeah it just be like that sometimes
#
# BrandonG1:
# when the game first came out i had like 17 kd and i was like there is no way i am that good right then found out it counts the bots laughing out loud
#
# SouthFLJay:
# i got into a gunfight with a trench gun user and he blasted me 3 times at maybe 10 meters and after i killed him i only had maybe 30 of my health missing

# %%
find_similar(df_tarkov, tarkov_embeddings_large)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ========== MIDDLE ==========
# p4nnus:
# there is hackers in every raid1 me and my 3 man just got all head eyesd withing 4s fuck this do something bsg
#
# ========== LEFT ==========
# Turok36:
# cringe
#
# regularknight:
# you see if you fold them a certain way you can fit so many
#
# RainingBlood78:
# i laughed so much man oh my god
#
# jabralta:
# guess what people will still play even bought a nioce after the lip smack sound laptop to play on the road in my sleeper berth so you chumps cannot out level me supply and demand you cannot get this kind of hit anywhere else its cool find the new items
#
# usprocksv2:
# if you die in a suspicious way whatsoever would you report the person killing you  yes or no that is as basic of a question i can ask
#
# ========== RIGHT ==========
# Cryovers:
# this is 100 offline raid  no other scavsbesides 1 or pmcs around laughing out loud
#
# Jaysterlo_:
# cheater problem aside this is fucking hilarious
#
# BurgerChurger69:
# exit camp factory with impacts
#
# Novel-Structure8660:
# i think you get killed from behind
#
# 0verStrike:
# dude first guy did a reversed entry he deserves that  who tf enters a room with their backs towards the entrance id you cleared outiside the next possible danger is inside the room laugh my ass off
#
# ========== TOP ==========
# d00b661:
# damn you must of been sweating laughing out loud
#
# Crashty:
# nice what item did you get out
#
# brxtin:
# interesting i got the exact same weekly with the rewards of 1 yellow card and 1 21ws card
#
# tipsykretts:
# no you got out played by a better player laughing out loud you knew where the spawns were and so did he you was doing the same thing he was doing trying to spawn kill him he just beat ya you could ran another way or hid but you turned
#
# CaladinDanse:
# reminder guys it is just a beta years later
#
# ========== BOTTOM ==========
# Qnasher:
# bro i bet that was some delicious scav karma
#
# clue2k:
# i am all for this honestly
#
# SpectreSquared:
# 8 hours in have had multiple similar interactions with you vets
#
# Dentalswarms:
# why would a bunch of former civilians just trying to survive be draw to a gunshot in a world full of dangerous pmc operatives no sense of self preservation
#
# Kamikaziklown:
# o7 may he headeyes the cheaters from the sky

# %%
find_similar(df_satis, satisfactory_embeddings_large)
# Out:
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\aidan\anaconda3\envs\reddit_scraping\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# ========== MIDDLE ==========
# jonnyfisch:
# better game performance i hate the lag spikes when chunks render
#
# ========== LEFT ==========
# Roseknight888:
# i would say an hour a day would be a perfectly reasonable game play loop though spend an hour setting up or polishing a production line or spend an hour exploring to find some resources
#
# US_Dept_of_Defence:
# when you have not logged in a hot minute and realize you were in the middle of fixing your spaghetti overwhelmed you decide to log off and leave that for the next time
#
# Hera_the_otter:
# remember there are no labor laws or unions in space
#
# Acrobatic-Truth:
# those who click play but never launch the game due to shit pc
#
# TobbieDatBoi:
# looks amazing man straight outta the future
#
# ========== RIGHT ==========
# Huntyoudownn:
# almost tempted to rebuy it just so i can rid my pc of epic games launcher once and for all
#
# MinaLamia:
# i have taken notes for three games satisfactory stardew and shadow empire
#
# kind of weird they all start with s
#
# Objective-Carob-5336:
# my 1 rule on steam is never under 50 off
#
# this rule has saved me so much money and helped refrain any shopping spree in the past
#
# SoleTwentyCharacters:
# wait till you get to turbo motors
#
# jorn86:
# can we please do things that will actually matter to the games quality instead
#
# ========== TOP ==========
# alfonsogonso:
# good mythical morning  satisfactory  good mythical factory it is just satisfactory but with even more gross food
#
# Laevend:
# i know right even the big bouncy bois that make whale noises whenever you hit them do not seem to drop anything either they do make great temporary trampolines though the birds make good target practice for bomb throwing now i am wondering if the large flying stingray can be
#
# Massakerss:
# 10
#
# TheAirsickLowlander:
# ruined king and derry girls not sure how this would work
#
# M05y:
# i have still never made it past tier 3
#
# ========== BOTTOM ==========
# 56Bot:
# me with 51km of conveyors at tier 4
#
# Ajumbleofwords:
# samurai jack  deep rock galatic
#
#
# basically just a normal samurai jack episode just with funny dwarves
#
# Xixitythefirst:
# beautiful work
#
# Beneficial-Virus1397:
# monica you want to talk about notes you want to talk about notes okay i have stumbled onto a major ficsit conspiracy beck how is that for notes becky what the hell are you talking about monica this companys efficiency is being sapped like unbalanced inputs becky and i got
#
# ManuFlosoYT:
# imgemotet5gs4649160imgemotet5gs46426948
